# %%
import pandas as pd

# %%
import pandas as pd

# Paths to the datasets
path1 = r"C:/Users/Admin/OneDrive/Documents/USIU_A/US2024/DSA1080/Group Project Data sets/NewCombined/combined_file_Spain_all_edited.csv"
path2 = r"C:/Users/Admin/OneDrive/Documents/USIU_A/US2024/DSA1080/Group Project Data sets/NewCombined/combined_file_Nairobi.csv"
path3 = r"C:/Users/Admin/OneDrive/Documents/USIU_A/US2024/DSA1080/Group Project Data sets/NewCombined/combined_Bucharest_Data.csv"
path4 = r"C:/Users/Admin/OneDrive/Documents/USIU_A/US2024/DSA1080/Group Project Data sets/NewCombined/combined_LA_Data.csv"
path5 = r"C:/Users/Admin/OneDrive/Documents/USIU_A/US2024/DSA1080/Group Project Data sets/combined_data_rome.xlsx"

# Load the datasets
data_Molina = pd.read_csv(path1)
data_nairobi = pd.read_csv(path2)
data_Bucharest = pd.read_csv(path3)
data_loS = pd.read_csv(path4)
data_rome = pd.read_excel(path5)

# %%
data_loS["unit"]="µg/m³"
data_loS.drop(columns=["valueo"], inplace=True)

# %%
data_nairobi["unit"].unique
data_loS
# Out:
#        location_id   location_name parameter   value   unit  \
# 0             8236  North Holywood       no2     5.8  µg/m³
# 1             8236  North Holywood       no2     7.6  µg/m³
# 2             8236  North Holywood       no2     7.7  µg/m³
# 3             8236  North Holywood       no2     7.8  µg/m³
# 4             8236  North Holywood       no2     9.7  µg/m³
# ...            ...             ...       ...     ...    ...
# 19376         8236  North Holywood      pm25  -100.0  µg/m³
# 19377         8236  North Holywood      pm25   800.0  µg/m³
# 19378         8236  North Holywood      pm25  3500.0  µg/m³
# 19379         8236  North Holywood      pm25  4000.0  µg/m³
# 19380         8236  North Holywood      pm25  7800.0  µg/m³
#
#                      datetimeUtc              datetimeLocal  \
# 0      2024-06-07T01:00:00+00:00  2024-06-06T18:00:00-07:00
# 1      2024-06-07T02:00:00+00:00  2024-06-06T19:00:00-07:00
# 2      2024-06-07T03:00:00+00:00  2024-06-06T20:00:00-07:00
# ...

# %%
# concatenate the datasets
data_combined = pd.concat([data_Molina, data_nairobi, data_Bucharest, data_loS, data_rome], ignore_index=True)

# Display the first few rows of the combined DataFrame
print(data_combined.head())
# Out:
#    location_id     location_name parameter  value   unit  \
# 0      2162458  MOLINA DE SEGURA        o3    6.2  µg/m³
# 1      2162458  MOLINA DE SEGURA        o3    7.5  µg/m³
# 2      2162458  MOLINA DE SEGURA        o3    9.2  µg/m³
# 3      2162458  MOLINA DE SEGURA        o3    6.3  µg/m³
# 4      2162458  MOLINA DE SEGURA        o3    5.5  µg/m³
#
#                  datetimeUtc              datetimeLocal       timezone  \
# 0  2024-02-06T01:00:00+00:00  2024-02-06T02:00:00+01:00  Europe/Madrid
# 1  2024-02-06T02:00:00+00:00  2024-02-06T03:00:00+01:00  Europe/Madrid
# 2  2024-02-06T03:00:00+00:00  2024-02-06T04:00:00+01:00  Europe/Madrid
# 3  2024-02-06T04:00:00+00:00  2024-02-06T05:00:00+01:00  Europe/Madrid
# 4  2024-02-06T05:00:00+00:00  2024-02-06T06:00:00+01:00  Europe/Madrid
#
#    latitude  longitude  country_iso  isMobile  isMonitor  \
# 0   38.0573    -1.2047          NaN       NaN        NaN
# 1   38.0573    -1.2047          NaN       NaN        NaN
# ...

# %%
# Introduction and Data Collection
#Data cleaning
# Drop duplicates
#

# %%
# Display basic information about the dataframe
print(data_combined.info())
print(data_combined.head())
# Handle missing values (example: fill NaNs with 0 for 'value')
data_combined['value'].fillna(0, inplace=True)

# Drop duplicates if any
data_combined.drop_duplicates(inplace=True)

# Display cleaned dataframe
print(data_combined.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64019 entries, 0 to 64018
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location_id    64019 non-null  int64
#  1   location_name  64019 non-null  object
#  2   parameter      64019 non-null  object
#  3   value          64019 non-null  float64
#  4   unit           64019 non-null  object
#  5   datetimeUtc    64019 non-null  object
#  6   datetimeLocal  64019 non-null  object
#  7   timezone       64019 non-null  object
#  8   latitude       64019 non-null  float64
#  9   longitude      64019 non-null  float64
#  10  country_iso    0 non-null      float64
#  11  isMobile       0 non-null      float64
#  12  isMonitor      0 non-null      float64
#  13  owner_name     64019 non-null  object
#  14  provider       64019 non-null  object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 7.3+ MB
# None
# ...

# %%
print(data_combined["parameter"].unique())
print(data_combined["location_name"].unique())
print(data_combined["unit"].unique())
# Out:
# ['o3' 'pm25' 'no2' 'pm10' 'so2' 'co' 'no' 'nox']
# ['MOLINA DE SEGURA' 'Nairobi' 'B-2' 'North Holywood' 'ARENULA']
# ['µg/m³']

# %%
# Name replacement
#Replace values in the location_name column
replacements = {
        "B-2": "Bucharest",
        "MOLINA DE SEGURA":"Madrid",
        "North Holywood": "Los Angeles",
        'ARENULA':"Rome"
        
    }
data_combined["location_name"] = data_combined["location_name"].replace(replacements)
    
    # Display the first few rows of the combined DataFrame
print(data_combined.head())
print(data_combined["location_name"].unique())
# Out:
#    location_id location_name parameter  value   unit  \
# 0      2162458        Madrid        o3    6.2  µg/m³
# 1      2162458        Madrid        o3    7.5  µg/m³
# 2      2162458        Madrid        o3    9.2  µg/m³
# 3      2162458        Madrid        o3    6.3  µg/m³
# 4      2162458        Madrid        o3    5.5  µg/m³
#
#                  datetimeUtc              datetimeLocal       timezone  \
# 0  2024-02-06T01:00:00+00:00  2024-02-06T02:00:00+01:00  Europe/Madrid
# 1  2024-02-06T02:00:00+00:00  2024-02-06T03:00:00+01:00  Europe/Madrid
# 2  2024-02-06T03:00:00+00:00  2024-02-06T04:00:00+01:00  Europe/Madrid
# 3  2024-02-06T04:00:00+00:00  2024-02-06T05:00:00+01:00  Europe/Madrid
# 4  2024-02-06T05:00:00+00:00  2024-02-06T06:00:00+01:00  Europe/Madrid
#
#    latitude  longitude  country_iso  isMobile  isMonitor  \
# 0   38.0573    -1.2047          NaN       NaN        NaN
# 1   38.0573    -1.2047          NaN       NaN        NaN
# ...

# %%
data_combined["location_name"].unique()
data_combined
# Out:
#        location_id location_name parameter  value   unit  \
# 0          2162458        Madrid        o3    6.2  µg/m³
# 1          2162458        Madrid        o3    7.5  µg/m³
# 2          2162458        Madrid        o3    9.2  µg/m³
# 3          2162458        Madrid        o3    6.3  µg/m³
# 4          2162458        Madrid        o3    5.5  µg/m³
# ...            ...           ...       ...    ...    ...
# 64014         7529          Rome      pm25   17.0  µg/m³
# 64015         7529          Rome      pm25   10.0  µg/m³
# 64016         7529          Rome      pm25    9.0  µg/m³
# 64017         7529          Rome      pm25   10.0  µg/m³
# 64018         7529          Rome      pm25   11.0  µg/m³
#
#                      datetimeUtc              datetimeLocal       timezone  \
# 0      2024-02-06T01:00:00+00:00  2024-02-06T02:00:00+01:00  Europe/Madrid
# 1      2024-02-06T02:00:00+00:00  2024-02-06T03:00:00+01:00  Europe/Madrid
# ...

# %%
data_combined.columns
# Out:
# Index(['location_id', 'location_name', 'parameter', 'value', 'unit',
#        'datetimeUtc', 'datetimeLocal', 'timezone', 'latitude', 'longitude',
#        'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider'],
#       dtype='object')

# %%
data_combined[["DateLocal", "TimeLocal1"]] = data_combined["datetimeLocal"].str.split("T", expand=True)
data_combined[["TimeLoc", "TimeLocal2"]] = data_combined["TimeLocal1"].str.split("+", expand=True)

data_combined[["DateUtc", "TimeUtc1"]] = data_combined["datetimeUtc"].str.split("T", expand=True)
data_combined[["TimeUtc", "TimeUtc2"]] = data_combined["TimeUtc1"].str.split("+", expand=True)
data_combined
# Out:
#        location_id location_name parameter  value   unit  \
# 0          2162458        Madrid        o3    6.2  µg/m³
# 1          2162458        Madrid        o3    7.5  µg/m³
# 2          2162458        Madrid        o3    9.2  µg/m³
# 3          2162458        Madrid        o3    6.3  µg/m³
# 4          2162458        Madrid        o3    5.5  µg/m³
# ...            ...           ...       ...    ...    ...
# 64014         7529          Rome      pm25   17.0  µg/m³
# 64015         7529          Rome      pm25   10.0  µg/m³
# 64016         7529          Rome      pm25    9.0  µg/m³
# 64017         7529          Rome      pm25   10.0  µg/m³
# 64018         7529          Rome      pm25   11.0  µg/m³
#
#                      datetimeUtc              datetimeLocal       timezone  \
# 0      2024-02-06T01:00:00+00:00  2024-02-06T02:00:00+01:00  Europe/Madrid
# 1      2024-02-06T02:00:00+00:00  2024-02-06T03:00:00+01:00  Europe/Madrid
# ...

# %%
# Convert the string to datetime
#data_combined['datetimeLocal'] = pd.to_datetime(data_combined['datetimeLocal'], errors='coerce')
data_combined["datetimeUtc"]=pd.to_datetime(data_combined["datetimeUtc"], errors='coerce')
# Then extract Date and Time
#data_combined['DateLocal'] = data_combined['datetimeLocal'].dt.date
#data_combined['TimeLocal'] = data_combined['datetimeLocal'].dt.time
data_combined['DateUtc'] = data_combined['datetimeUtc'].dt.date
data_combined['TimeUtc'] = data_combined['datetimeUtc'].dt.time

data_combined.head()
# Out:
#    location_id location_name parameter  value   unit  \
# 0      2162458        Madrid        o3    6.2  µg/m³
# 1      2162458        Madrid        o3    7.5  µg/m³
# 2      2162458        Madrid        o3    9.2  µg/m³
# 3      2162458        Madrid        o3    6.3  µg/m³
# 4      2162458        Madrid        o3    5.5  µg/m³
#
#                 datetimeUtc              datetimeLocal       timezone  \
# 0 2024-02-06 01:00:00+00:00  2024-02-06 02:00:00+01:00  Europe/Madrid
# 1 2024-02-06 02:00:00+00:00  2024-02-06 03:00:00+01:00  Europe/Madrid
# 2 2024-02-06 03:00:00+00:00  2024-02-06 04:00:00+01:00  Europe/Madrid
# 3 2024-02-06 04:00:00+00:00  2024-02-06 05:00:00+01:00  Europe/Madrid
# 4 2024-02-06 05:00:00+00:00  2024-02-06 06:00:00+01:00  Europe/Madrid
#
#    latitude  longitude  ...                         owner_name  provider  \
# 0   38.0573    -1.2047  ...  Unknown Governmental Organization       EEA
# 1   38.0573    -1.2047  ...  Unknown Governmental Organization       EEA
# ...

# %%
data_combined.columns
# Out:
# Index(['location_id', 'location_name', 'parameter', 'value', 'unit',
#        'datetimeUtc', 'datetimeLocal', 'timezone', 'latitude', 'longitude',
#        'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider',
#        'DateLocal', 'TimeLocal', 'DateUtc', 'TimeUtc'],
#       dtype='object')

# %%
#data_combined.drop(columns=['country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider'], inplace=True)
data_combined.columns
# Out:
# Index(['location_id', 'location_name', 'parameter', 'value', 'unit',
#        'datetimeUtc', 'datetimeLocal', 'timezone', 'latitude', 'longitude',
#        'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider',
#        'DateLocal', 'TimeLocal1', 'TimeLoc', 'TimeLocal2', 'DateUtc',
#        'TimeUtc1', 'TimeUtc', 'TimeUtc2'],
#       dtype='object')

# %%
# # Assuming data_Molina is already loaded with the relevant columns
# # Convert 'DateLocal' to datetime format
# data_combined['DateLocal'] = pd.to_datetime(data_combined['DateLocal'])

# Display the info of 'DateLocal' column to verify the conversion
print(data_combined["DateLocal"].info())

# Display the first few rows of the DataFrame to verify changes
print(data_combined.head())

# Convert 'TimeLoc' to time format
# data_combined['TimeLocal'] = pd.to_datetime(data_combined['TimeLocal'], format='%H:%M:%S').dt.time

# Convert 'DateUtc' to datetime format
data_combined['DateUtc'] = pd.to_datetime(data_combined['DateUtc'])

# Convert 'TimeUtc' to time format
data_combined['TimeUtc'] = pd.to_datetime(data_combined['TimeUtc'], format='%H:%M:%S').dt.time

# Display the updated DataFrame to verify all changes
print(data_combined.head())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 58536 entries, 0 to 64018
# Series name: DateLocal
# Non-Null Count  Dtype
# --------------  -----
# 58536 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 914.6 KB
# None
#    location_id location_name parameter  value   unit  \
# 0      2162458        Madrid        o3    6.2  µg/m³
# 1      2162458        Madrid        o3    7.5  µg/m³
# 2      2162458        Madrid        o3    9.2  µg/m³
# 3      2162458        Madrid        o3    6.3  µg/m³
# 4      2162458        Madrid        o3    5.5  µg/m³
#
#                 datetimeUtc              datetimeLocal       timezone  \
# 0 2024-02-06 01:00:00+00:00  2024-02-06 02:00:00+01:00  Europe/Madrid
# 1 2024-02-06 02:00:00+00:00  2024-02-06 03:00:00+01:00  Europe/Madrid
# 2 2024-02-06 03:00:00+00:00  2024-02-06 04:00:00+01:00  Europe/Madrid
# 3 2024-02-06 04:00:00+00:00  2024-02-06 05:00:00+01:00  Europe/Madrid
# ...

# %%
# # Check for NaN values in the entire DataFrame
# print(data_Molina.isna())

# # Check if there are any NaN values in each column
# print(data_Molina.isna().any())

# %%
# # Recasting to day and hour
# data_combined['DateLocal']=pd.to_datetime(data_combined['DateLocal'])
# data_combined["DateLocal"].info()
# data_combined.head()
# data_Molina.DateLocal.astype(date)
# Convert 'TimeLoc' to time format
#data_combined['TimeLocal'] = pd.to_datetime(data_combined['TimeLocal'], format='%H:%M:%S').dt.time
# data_Molina['DateUtc'].dt.day
data_combined['DateUtc']=pd.to_datetime(data_combined['DateUtc'])
# Convert 'TimeLoc' to time format
data_combined['TimeUtc'] = pd.to_datetime(data_combined['TimeUtc'], format='%H:%M:%S').dt.time

# %%
print(data_combined['DateLocal'].isna().sum())
print(data_combined["DateUtc"].isna().sum())
# Out:
# 0
# 0

# %%
#Add a new column 'DayOfWeek' with the day of the week name
data_combined['DayOfWeek'] = data_combined["DateUtc"].apply(lambda x: x.strftime('%A'))
data_combined
# Out:
#        location_id location_name parameter  value   unit  \
# 0          2162458        Madrid        o3    6.2  µg/m³
# 1          2162458        Madrid        o3    7.5  µg/m³
# 2          2162458        Madrid        o3    9.2  µg/m³
# 3          2162458        Madrid        o3    6.3  µg/m³
# 4          2162458        Madrid        o3    5.5  µg/m³
# ...            ...           ...       ...    ...    ...
# 64014         7529          Rome      pm25   17.0  µg/m³
# 64015         7529          Rome      pm25   10.0  µg/m³
# 64016         7529          Rome      pm25    9.0  µg/m³
# 64017         7529          Rome      pm25   10.0  µg/m³
# 64018         7529          Rome      pm25   11.0  µg/m³
#
#                     datetimeUtc              datetimeLocal       timezone  \
# 0     2024-02-06 01:00:00+00:00  2024-02-06 02:00:00+01:00  Europe/Madrid
# 1     2024-02-06 02:00:00+00:00  2024-02-06 03:00:00+01:00  Europe/Madrid
# ...

# %%
# Sample data loading
# path = 'path_to_your_file.csv'
# data_combined = pd.read_csv(path)

# Convert 'DateLocal' to datetime if not already done
data_combined['DateLocal'] = pd.to_datetime(data_combined['DateLocal'], errors='coerce')

# Handle missing values in 'DateLocal' if necessary
data_combined['DateLocal'] = data_combined['DateLocal'].fillna(pd.Timestamp('1900-01-01'))

# Sort by 'location_name' and then by 'DateLocal'
data_combined_sorted = data_combined.sort_values(by=['location_name', 'DateLocal'])

# Verify the sorting
print(data_combined_sorted.head())
# Out:
#        location_id location_name parameter  value   unit  \
# 20919      2163091     Bucharest      pm10   14.0  µg/m³
# 20920      2163091     Bucharest      pm10   14.0  µg/m³
# 20921      2163091     Bucharest      pm10   15.0  µg/m³
# 20922      2163091     Bucharest      pm10   15.0  µg/m³
# 20923      2163091     Bucharest      pm10   15.0  µg/m³
#
#                     datetimeUtc              datetimeLocal          timezone  \
# 20919 2024-01-28 23:00:00+00:00  2024-01-29 01:00:00+02:00  Europe/Bucharest
# 20920 2024-01-29 00:00:00+00:00  2024-01-29 02:00:00+02:00  Europe/Bucharest
# 20921 2024-01-29 01:00:00+00:00  2024-01-29 03:00:00+02:00  Europe/Bucharest
# 20922 2024-01-29 02:00:00+00:00  2024-01-29 04:00:00+02:00  Europe/Bucharest
# 20923 2024-01-29 03:00:00+00:00  2024-01-29 05:00:00+02:00  Europe/Bucharest
#
#         latitude  longitude  ...  provider  DateLocal      TimeLocal1  \
# 20919  44.417967  26.160786  ...       EEA 2024-01-29  01:00:00+02:00
# ...

# %%
print(data_combined_sorted["parameter"].value_counts())
print(data_combined_sorted["location_name"].value_counts())
print(data_combined_sorted["DateUtc"].value_counts())
# Out:
# parameter
# no2     13221
# o3      10774
# pm25     9797
# no       8079
# nox      8073
# pm10     5201
# so2      2496
# co        895
# Name: count, dtype: int64
# location_name
# Los Angeles    19381
# Rome           17547
# Madrid          9869
# Bucharest       8420
# Nairobi         3319
# Name: count, dtype: int64
# DateUtc
# 2024-02-20    431
# 2024-02-19    431
# 2024-02-17    430
# 2024-02-22    430
# 2024-02-18    430
#              ...
# 2024-01-04     95
# 2024-01-03     95
# 2024-01-02     95
# 2024-01-01     89
# 2024-07-04     10
# Name: count, Length: 186, dtype: int64

# %%
print(data_combined_sorted["DayOfWeek"].unique())
data_combined_sorted=data_combined_sorted.drop(columns=["datetimeLocal","TimeLocal"])
data_combined_sorted
# Out:
# ['Tuesday' 'Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday' 'Monday']
#        location_id location_name parameter  value   unit  \
# 13313      2163091     Bucharest      pm10   34.0  µg/m³
# 13314      2163091     Bucharest      pm10   32.0  µg/m³
# 13315      2163091     Bucharest      pm10   30.0  µg/m³
# 13316      2163091     Bucharest      pm10   34.0  µg/m³
# 13317      2163091     Bucharest      pm10   31.0  µg/m³
# ...            ...           ...       ...    ...    ...
# 48929         7529          Rome       nox   16.0  µg/m³
# 49668         7529          Rome        o3   68.0  µg/m³
# 49669         7529          Rome        o3   71.0  µg/m³
# 49801         7529          Rome      pm10  130.0  µg/m³
# 49840         7529          Rome      pm25   17.0  µg/m³
#
#                     datetimeUtc          timezone   latitude  longitude  \
# 13313 2024-06-04 01:00:00+00:00  Europe/Bucharest  44.417967  26.160786
# ...

# %%
print(data_combined_sorted.isna().sum())
# Out:
# location_id      0
# location_name    0
# parameter        0
# value            0
# unit             0
# datetimeUtc      0
# timezone         0
# latitude         0
# longitude        0
# DateLocal        0
# DateUtc          0
# TimeUtc          0
# DayOfWeek        0
# dtype: int64

# %%
data_combined_sorted["location_name"].unique()
# Out:
# array(['Bucharest', 'Los Angeles', 'Madrid', 'Nairobi', 'Rome'],
#       dtype=object)

# %%
import holidays

# Define the year you want to fetch holidays for
year = 2024

# Romania (Bucharest)
ro_holidays = holidays.RO(years=year)
print("Romania Holidays:")
for date, name in sorted(ro_holidays.items()):
    print(f"{date}: {name}")

# USA (Los Angeles)
us_holidays = holidays.US(years=year)
print("\nUSA Holidays:")
for date, name in sorted(us_holidays.items()):
    print(f"{date}: {name}")

# Spain (Madrid)
es_holidays = holidays.ES(years=year)
print("\nSpain Holidays:")
for date, name in sorted(es_holidays.items()):
    print(f"{date}: {name}")

# Kenya (Nairobi)
ke_holidays = holidays.KE(years=year)
print("\nKenya Holidays:")
for date, name in sorted(ke_holidays.items()):
    print(f"{date}: {name}")

# Italy (Rome)
it_holidays = holidays.IT(years=year)
print("\nItaly Holidays:")
for date, name in sorted(it_holidays.items()):
    print(f"{date}: {name}")
# Out:
# Romania Holidays:
# 2024-01-01: Anul Nou
# 2024-01-02: Anul Nou
# 2024-01-06: Bobotează
# 2024-01-07: Sfântul Ion
# 2024-01-24: Ziua Unirii Principatelor Române
# 2024-05-01: Ziua Muncii
# 2024-05-03: Paștele
# 2024-05-05: Paștele
# 2024-05-06: Paștele
# 2024-06-01: Ziua Copilului
# 2024-06-23: Rusaliile
# 2024-06-24: Rusaliile
# 2024-08-15: Adormirea Maicii Domnului
# 2024-11-30: Sfantul Apostol Andrei cel Intai chemat
# 2024-12-01: Ziua Națională a României
# 2024-12-25: Crăciunul
# 2024-12-26: Crăciunul
#
# USA Holidays:
# 2024-01-01: New Year's Day
# 2024-01-15: Martin Luther King Jr. Day
# 2024-02-19: Washington's Birthday
# 2024-05-27: Memorial Day
# 2024-06-19: Juneteenth National Independence Day
# 2024-07-04: Independence Day
# 2024-09-02: Labor Day
# 2024-10-14: Columbus Day
# 2024-11-11: Veterans Day
# 2024-11-28: Thanksgiving
# 2024-12-25: Christmas Day
#
# Spain Holidays:
# 2024-01-01: Año nuevo
# 2024-01-06: Epifanía del Señor
# 2024-03-29: Viernes Santo
# ...

# %%
import pandas as pd
import holidays

# Load your data into a DataFrame
# data_combined = pd.read_csv('path_to_your_combined_data.csv')  # Adjust path as needed

# Define function to get holiday name based on location
def get_holiday_name(date, location):
    year = date.year
    if location == 'Bucharest':
        ro_holidays = holidays.RO(years=year)
        return ro_holidays.get(date, None)
    elif location == 'Los Angeles':
        us_holidays = holidays.US(years=year)
        return us_holidays.get(date, None)
    elif location == 'Madrid':
        es_holidays = holidays.ES(years=year)
        return es_holidays.get(date, None)
    elif location == 'Nairobi':
        ke_holidays = holidays.KE(years=year)
        return ke_holidays.get(date, None)
    elif location == 'Rome':
        it_holidays = holidays.IT(years=year)
        return it_holidays.get(date, None)
    else:
        return None

# Define function to get the day type description
def get_day_description(date, holiday_name):
    day_of_week = date.day_name()
    if holiday_name:
        return holiday_name
    elif day_of_week in ['Saturday', 'Sunday']:
        return 'Weekend Day'
    else:
        return 'Working Day'

# Apply the function to add the holiday name column
def add_holiday_column(df):
    df['HolidayName'] = df.apply(lambda row: get_holiday_name(row['DateLocal'], row['location_name']), axis=1)
    return df

# Apply the function to add the day description column
def add_day_description_column(df):
    df['DayDescription'] = df.apply(lambda row: get_day_description(row['DateLocal'], row['HolidayName']), axis=1)
    return df

# Ensure DateLocal is in datetime format
data_combined_sorted['DateLocal'] = pd.to_datetime(data_combined_sorted['DateLocal'])

# Add the holiday name column and the day description column
data_combined_sorted = add_holiday_column(data_combined_sorted)
data_combined_sorted = add_day_description_column(data_combined_sorted)

# Check the updated DataFrame
print(data_combined_sorted.head())
# Out:
#        location_id location_name parameter  value   unit  \
# 20919      2163091     Bucharest      pm10   14.0  µg/m³
# 20920      2163091     Bucharest      pm10   14.0  µg/m³
# 20921      2163091     Bucharest      pm10   15.0  µg/m³
# 20922      2163091     Bucharest      pm10   15.0  µg/m³
# 20923      2163091     Bucharest      pm10   15.0  µg/m³
#
#                     datetimeUtc              datetimeLocal          timezone  \
# 20919 2024-01-28 23:00:00+00:00  2024-01-29 01:00:00+02:00  Europe/Bucharest
# 20920 2024-01-29 00:00:00+00:00  2024-01-29 02:00:00+02:00  Europe/Bucharest
# 20921 2024-01-29 01:00:00+00:00  2024-01-29 03:00:00+02:00  Europe/Bucharest
# 20922 2024-01-29 02:00:00+00:00  2024-01-29 04:00:00+02:00  Europe/Bucharest
# 20923 2024-01-29 03:00:00+00:00  2024-01-29 05:00:00+02:00  Europe/Bucharest
#
#         latitude  longitude  ...      TimeLocal1   TimeLoc  TimeLocal2  \
# 20919  44.417967  26.160786  ...  01:00:00+02:00  01:00:00       02:00
# ...

# %%
#data_combined_sorted=data_combined_sorted.drop(columns=["HolidayName"],inplace=True)
data_combined_sorted
# Out:
#        location_id location_name parameter  value   unit  \
# 13313      2163091     Bucharest      pm10   34.0  µg/m³
# 13314      2163091     Bucharest      pm10   32.0  µg/m³
# 13315      2163091     Bucharest      pm10   30.0  µg/m³
# 13316      2163091     Bucharest      pm10   34.0  µg/m³
# 13317      2163091     Bucharest      pm10   31.0  µg/m³
# ...            ...           ...       ...    ...    ...
# 48929         7529          Rome       nox   16.0  µg/m³
# 49668         7529          Rome        o3   68.0  µg/m³
# 49669         7529          Rome        o3   71.0  µg/m³
# 49801         7529          Rome      pm10  130.0  µg/m³
# 49840         7529          Rome      pm25   17.0  µg/m³
#
#                     datetimeUtc          timezone   latitude  longitude  \
# 13313 2024-06-04 01:00:00+00:00  Europe/Bucharest  44.417967  26.160786
# 13314 2024-06-04 02:00:00+00:00  Europe/Bucharest  44.417967  26.160786
# ...

# %%
data_combined_sorted["parameter"].unique()
# Out:
# array(['pm10', 'so2', 'co', 'no2', 'no', 'o3', 'nox', 'pm25'],
#       dtype=object)

# %%
import pandas as pd

# Check columns in the DataFrame
print(data_combined_sorted.columns)

# Filter and select columns for each pollutant from data_combined
df_combined_O3 = data_combined_sorted[data_combined_sorted["parameter"] == "o3"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "O3"})

df_combined_PM25 = data_combined_sorted[data_combined_sorted["parameter"] == "pm25"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "PM2.5"})

df_combined_NO2 = data_combined_sorted[data_combined_sorted["parameter"] == "no2"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "NO2"})

df_combined_PM10 = data_combined_sorted[data_combined_sorted["parameter"] == "pm10"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "PM10"})

df_combined_CO = data_combined_sorted[data_combined_sorted["parameter"] == "co"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "CO"})

df_combined_NO = data_combined_sorted[data_combined_sorted["parameter"] == "no"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "NO"})

df_combined_NOx = data_combined_sorted[data_combined_sorted["parameter"] == "nox"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "NOx"})

df_combined_SO2 = data_combined_sorted[data_combined_sorted["parameter"] == "so2"][
    ["location_id", "location_name", "value", "unit", "timezone", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"]
].rename(columns={"value": "SO2"})

# Drop conflicting columns before merging
columns_to_drop = ["timezone", "unit"]  # Modify based on your actual conflict
df_combined_O3 = df_combined_O3.drop(columns=columns_to_drop)
df_combined_PM25 = df_combined_PM25.drop(columns=columns_to_drop)
df_combined_NO2 = df_combined_NO2.drop(columns=columns_to_drop)
df_combined_PM10 = df_combined_PM10.drop(columns=columns_to_drop)
df_combined_CO = df_combined_CO.drop(columns=columns_to_drop)
df_combined_NO = df_combined_NO.drop(columns=columns_to_drop)
df_combined_NOx = df_combined_NOx.drop(columns=columns_to_drop)
df_combined_SO2 = df_combined_SO2.drop(columns=columns_to_drop)

# Merge DataFrames on common columns
data_combined_sorted = df_combined_O3 \
    .merge(df_combined_PM25, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer") \
    .merge(df_combined_NO2, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer") \
    .merge(df_combined_PM10, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer") \
    .merge(df_combined_CO, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer") \
    .merge(df_combined_NO, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer") \
    .merge(df_combined_NOx, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer") \
    .merge(df_combined_SO2, on=["location_id", "location_name", "DateLocal", "DateUtc", "TimeUtc", "DayOfWeek", "DayDescription"], how="outer")

# Sort the combined DataFrame by location_name and DateLocal
data_combined_sorted = data_combined_sorted.sort_values(by=["location_name", "DateLocal"])

# Reset index for better readability
data_combined_sorted.reset_index(drop=True, inplace=True)

# Display the sorted DataFrame
print("Combined and Sorted DataFrame:")
print(data_combined_sorted.head())
# Out:
# Index(['location_id', 'location_name', 'parameter', 'value', 'unit',
#        'datetimeUtc', 'datetimeLocal', 'timezone', 'latitude', 'longitude',
#        'country_iso', 'isMobile', 'isMonitor', 'owner_name', 'provider',
#        'DateLocal', 'TimeLocal1', 'TimeLoc', 'TimeLocal2', 'DateUtc',
#        'TimeUtc1', 'TimeUtc', 'TimeUtc2', 'DayOfWeek', 'HolidayName',
#        'DayDescription'],
#       dtype='object')
# Combined and Sorted DataFrame:
#    location_id location_name  O3  DateLocal    DateUtc   TimeUtc DayOfWeek  \
# 0      2163091     Bucharest NaN 2024-01-29 2024-01-28  23:00:00    Sunday
# 1      2163091     Bucharest NaN 2024-01-29 2024-01-29  00:00:00    Monday
# 2      2163091     Bucharest NaN 2024-01-29 2024-01-29  01:00:00    Monday
# 3      2163091     Bucharest NaN 2024-01-29 2024-01-29  02:00:00    Monday
# 4      2163091     Bucharest NaN 2024-01-29 2024-01-29  03:00:00    Monday
#
#   DayDescription  PM2.5   NO2  PM10     CO  NO  NOx  SO2
# ...

# %%
data_nairobi.head()
# Out:
#    location_id location_name parameter  value   unit  \
# 0      2156118       Nairobi      pm25   13.0  µg/m³
# 1      2156118       Nairobi      pm25    7.2  µg/m³
# 2      2156118       Nairobi      pm25    7.2  µg/m³
# 3      2156118       Nairobi      pm25    6.6  µg/m³
# 4      2156118       Nairobi      pm25   15.0  µg/m³
#
#                  datetimeUtc              datetimeLocal        timezone  \
# 0  2024-03-03T01:00:00+00:00  2024-03-03T04:00:00+03:00  Africa/Nairobi
# 1  2024-03-03T02:00:00+00:00  2024-03-03T05:00:00+03:00  Africa/Nairobi
# 2  2024-03-03T03:00:00+00:00  2024-03-03T06:00:00+03:00  Africa/Nairobi
# 3  2024-03-03T04:00:00+00:00  2024-03-03T07:00:00+03:00  Africa/Nairobi
# 4  2024-03-03T05:00:00+00:00  2024-03-03T08:00:00+03:00  Africa/Nairobi
#
#    latitude  longitude  country_iso  isMobile  isMonitor owner_name provider
# 0  -1.33159   36.91271          NaN       NaN        NaN    Clarity  Clarity
# ...

# %%
data_combined_sorted[data_combined_sorted["location_name"]=="Nairobi"]
# Out:
#        location_id location_name  O3  DateLocal    DateUtc   TimeUtc  \
# 8944       2156118       Nairobi NaN 2024-01-28 2024-01-28  16:00:00
# 8945       2156118       Nairobi NaN 2024-01-28 2024-01-28  17:00:00
# 8946       2156118       Nairobi NaN 2024-01-28 2024-01-28  18:00:00
# 8947       2156118       Nairobi NaN 2024-01-28 2024-01-28  19:00:00
# 8948       2156118       Nairobi NaN 2024-01-28 2024-01-28  20:00:00
# ...            ...           ...  ..        ...        ...       ...
# 12258      2156118       Nairobi NaN 2024-07-03 2024-07-03  17:00:00
# 12259      2156118       Nairobi NaN 2024-07-03 2024-07-03  19:00:00
# 12260      2156118       Nairobi NaN 2024-07-04 2024-07-03  21:00:00
# 12261      2156118       Nairobi NaN 2024-07-04 2024-07-03  22:00:00
# 12262      2156118       Nairobi NaN 2024-07-04 2024-07-03  23:00:00
#
#        DayOfWeek DayDescription  PM2.5  NO2  PM10  CO  NO  NOx  SO2
# 8944      Sunday    Weekend Day    6.4  NaN   NaN NaN NaN  NaN  NaN
# ...

# %%
data_combined_sorted.isna().sum()
# Out:
# location_id           0
# location_name         0
# O3                 5916
# DateLocal             0
# DateUtc               0
# TimeUtc               0
# DayOfWeek             0
# DayDescription        0
# PM2.5              6893
# NO2                3469
# PM10              11489
# CO                15795
# NO                 8611
# NOx                8617
# SO2               14194
# dtype: int64

# %%
import pandas as pd

# Assuming data_combined_sorted is your DataFrame
# List of pollutants
pollutants = ['O3', 'PM10', 'PM2.5', 'NO2', 'CO', 'NO', 'NOx', 'SO2']

# Define city-specific pollutant availability
city_pollutants = {
    'Nairobi': ['PM2.5'],
    'Rome': ['NO', 'NOx', 'O3', 'PM10', 'PM2.5', 'NO2'],
    'Madrid': ['O3', 'PM10', 'PM2.5', 'NO2'],
    'Los Angeles': ['NOx', 'O3', 'PM2.5', 'NO2', 'NO'],
    'Bucharest': ['PM10', 'NO2', 'SO2', 'CO']
}

# Function to clean pollutants based on city-specific availability
def clean_pollutants(row, city_pollutants):
    city = row['location_name']
    available_pollutants = city_pollutants[city]
    for pollutant in pollutants:
        if pollutant not in available_pollutants:
            row[pollutant] = 0
    return row

# Apply the cleaning function
data_combined_sorted = data_combined_sorted.apply(clean_pollutants, city_pollutants=city_pollutants, axis=1)

# Print the cleaned DataFrame to verify
print("Cleaned DataFrame:")
print(data_combined_sorted.head())
# Out:
# Cleaned DataFrame:
#    location_id location_name   O3  DateLocal    DateUtc   TimeUtc DayOfWeek  \
# 0      2163091     Bucharest  0.0 2024-01-29 2024-01-28  23:00:00    Sunday
# 1      2163091     Bucharest  0.0 2024-01-29 2024-01-29  00:00:00    Monday
# 2      2163091     Bucharest  0.0 2024-01-29 2024-01-29  01:00:00    Monday
# 3      2163091     Bucharest  0.0 2024-01-29 2024-01-29  02:00:00    Monday
# 4      2163091     Bucharest  0.0 2024-01-29 2024-01-29  03:00:00    Monday
#
#   DayDescription  PM2.5   NO2  PM10     CO   NO  NOx  SO2
# 0    Working Day    0.0  47.0  14.0  610.0  0.0  0.0  4.0
# 1    Working Day    0.0  43.0  14.0  600.0  0.0  0.0  4.0
# 2    Working Day    0.0  37.0  15.0  610.0  0.0  0.0  4.0
# 3    Working Day    0.0  33.0  15.0  580.0  0.0  0.0  NaN
# 4    Working Day    0.0   NaN  15.0  600.0  0.0  0.0  4.0

# %%
# import pandas as pd

# # Sample DataFrame (replace with your actual DataFrame)
# # clean_data1 = pd.DataFrame({...})

# # List of pollutants
# pollutants = ['O3', 'PM10', 'PM2.5', 'NO2', 'CO', 'NO', 'NOx', 'SO2']

# # Set all other pollutants to zero for Nairobi, except PM2.5
# data_combined_sorted.loc[data_combined_sorted['location_name'] == 'Nairobi', pollutants] = data_combined_sorted.loc[data_combined_sorted['location_name'] == 'Nairobi', pollutants].apply(lambda row: row if row.name == 'PM2.5' else 0, axis=1)

# # Print the cleaned DataFrame to verify
# print("Cleaned DataFrame for Nairobi:")
# print(data_combined_sorted[data_combined_sorted['location_name'] == 'Nairobi'].head())

# %%
# Interpolate missing values
pivoted_df_interpolated = data_combined_sorted.interpolate()
# Backward fill missing values
print(pivoted_df_interpolated.isna().sum())
# Out:
# location_id       0
# location_name     0
# O3                0
# DateLocal         0
# DateUtc           0
# TimeUtc           0
# DayOfWeek         0
# DayDescription    0
# PM2.5             0
# NO2               0
# PM10              0
# CO                0
# NO                0
# NOx               0
# SO2               0
# dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17348\2735308306.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   pivoted_df_interpolated = data_combined_sorted.interpolate()

# %%
clean_data1= pivoted_df_interpolated.fillna(method='bfill')
clean_data1.isna().sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17348\1724255191.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   clean_data1= pivoted_df_interpolated.fillna(method='bfill')
# location_id       0
# location_name     0
# O3                0
# DateLocal         0
# DateUtc           0
# TimeUtc           0
# DayOfWeek         0
# DayDescription    0
# PM2.5             0
# NO2               0
# PM10              0
# CO                0
# NO                0
# NOx               0
# SO2               0
# dtype: int64

# %%
clean_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16690 entries, 0 to 16689
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location_id     16690 non-null  int64
#  1   location_name   16690 non-null  object
#  2   O3              16690 non-null  float64
#  3   DateLocal       16690 non-null  datetime64[ns]
#  4   DateUtc         16690 non-null  datetime64[ns]
#  5   TimeUtc         16690 non-null  object
#  6   DayOfWeek       16690 non-null  object
#  7   DayDescription  16690 non-null  object
#  8   PM2.5           16690 non-null  float64
#  9   NO2             16690 non-null  float64
#  10  PM10            16690 non-null  float64
#  11  CO              16690 non-null  float64
#  12  NO              16690 non-null  float64
#  13  NOx             16690 non-null  float64
#  14  SO2             16690 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(1), object(4)
# ...

# %%
import pandas as pd

# Example DataFrame
# clean_data1 = pd.read_csv('your_data.csv') # Load your DataFrame

# Define valid ranges for each pollutant
valid_ranges = {
    'O3': (0, 500),
    'PM2.5': (0, 500),
    'NO2': (0, 500),
    'PM10': (0, 500),
    'CO': (0, 50),
    'NO': (0, 500),
    'NOx': (0, 500)
}

# Function to adjust values based on valid ranges
def adjust_values(df, column, min_val, max_val):
    df[column] = df[column].apply(lambda x: min(max(x, min_val), max_val))
    return df

# Apply adjustments based on valid ranges
for pollutant, (min_val, max_val) in valid_ranges.items():
    adjust_values(clean_data1, pollutant, min_val, max_val)

# Print the adjusted DataFrame
print("Adjusted DataFrame:")
print(clean_data1.head())
# Out:
# Adjusted DataFrame:
#    location_id location_name   O3  DateLocal    DateUtc   TimeUtc DayOfWeek  \
# 0      2163091     Bucharest  0.0 2024-01-29 2024-01-28  23:00:00    Sunday
# 1      2163091     Bucharest  0.0 2024-01-29 2024-01-29  00:00:00    Monday
# 2      2163091     Bucharest  0.0 2024-01-29 2024-01-29  01:00:00    Monday
# 3      2163091     Bucharest  0.0 2024-01-29 2024-01-29  02:00:00    Monday
# 4      2163091     Bucharest  0.0 2024-01-29 2024-01-29  03:00:00    Monday
#
#   DayDescription  PM2.5   NO2  PM10    CO   NO  NOx  SO2
# 0    Working Day    0.0  47.0  14.0  50.0  0.0  0.0  4.0
# 1    Working Day    0.0  43.0  14.0  50.0  0.0  0.0  4.0
# 2    Working Day    0.0  37.0  15.0  50.0  0.0  0.0  4.0
# 3    Working Day    0.0  33.0  15.0  50.0  0.0  0.0  4.0
# 4    Working Day    0.0  40.0  15.0  50.0  0.0  0.0  4.0

# %%
import pandas as pd
import numpy as np

# Define the linear scaling function
def linear_scale(value, old_min, old_max, new_min, new_max):
    return ((value - old_min) * (new_max - new_min) / (old_max - old_min)) + new_min

# Define AQI calculation functions for different pollutants
def calculate_aqi_pm25(value):
    if value <= 12.0:
        return linear_scale(value, 0, 12, 0, 50)
    elif value <= 35.4:
        return linear_scale(value, 12.1, 35.4, 51, 100)
    elif value <= 55.4:
        return linear_scale(value, 35.5, 55.4, 101, 150)
    elif value <= 150.4:
        return linear_scale(value, 55.5, 150.4, 151, 200)
    elif value <= 250.4:
        return linear_scale(value, 150.5, 250.4, 201, 300)
    elif value <= 350.4:
        return linear_scale(value, 250.5, 350.4, 301, 400)
    elif value <= 500.4:
        return linear_scale(value, 350.5, 500.4, 401, 500)
    else:
        return 500  # AQI value capped at 500 for PM2.5

def calculate_aqi_o3(value):
    if value <= 54:
        return linear_scale(value, 0, 54, 0, 50)
    elif value <= 70:
        return linear_scale(value, 55, 70, 51, 100)
    elif value <= 85:
        return linear_scale(value, 71, 85, 101, 150)
    elif value <= 105:
        return linear_scale(value, 86, 105, 151, 200)
    elif value <= 200:
        return linear_scale(value, 106, 200, 201, 300)
    elif value <= 504:
        return linear_scale(value, 201, 504, 301, 400)
    else:
        return 500  # AQI value capped at 500 for O3

def calculate_aqi_no2(value):
    if value <= 53:
        return linear_scale(value, 0, 53, 0, 50)
    elif value <= 100:
        return linear_scale(value, 54, 100, 51, 100)
    elif value <= 360:
        return linear_scale(value, 101, 360, 101, 150)
    elif value <= 649:
        return linear_scale(value, 361, 649, 151, 200)
    elif value <= 1249:
        return linear_scale(value, 650, 1249, 201, 300)
    elif value <= 2049:
        return linear_scale(value, 1250, 2049, 301, 400)
    else:
        return 500  # AQI value capped at 500 for NO2

def calculate_aqi_pm10(value):
    if value <= 54:
        return linear_scale(value, 0, 54, 0, 50)
    elif value <= 154:
        return linear_scale(value, 55, 154, 51, 100)
    elif value <= 254:
        return linear_scale(value, 155, 254, 101, 150)
    elif value <= 354:
        return linear_scale(value, 255, 354, 151, 200)
    elif value <= 424:
        return linear_scale(value, 355, 424, 201, 300)
    elif value <= 504:
        return linear_scale(value, 425, 504, 301, 400)
    else:
        return 500  # AQI value capped at 500 for PM10

def calculate_aqi_co(value):
    if value <= 4.4:
        return linear_scale(value, 0, 4.4, 0, 50)
    elif value <= 9.4:
        return linear_scale(value, 4.5, 9.4, 51, 100)
    elif value <= 12.4:
        return linear_scale(value, 9.5, 12.4, 101, 150)
    elif value <= 15.4:
        return linear_scale(value, 12.5, 15.4, 151, 200)
    elif value <= 30.4:
        return linear_scale(value, 15.5, 30.4, 201, 300)
    elif value <= 40.4:
        return linear_scale(value, 30.5, 40.4, 301, 400)
    elif value <= 50.4:
        return linear_scale(value, 40.5, 50.4, 401, 500)
    else:
        return 500  # AQI value capped at 500 for CO

def calculate_aqi_no(value):
    return 0  # Placeholder, as NO typically isn't directly converted to AQI

def calculate_aqi_nox(value):
    return 0  # Placeholder, as NOx typically isn't directly converted to AQI

def calculate_aqi_so2(value):
    if value <= 35:
        return linear_scale(value, 0, 35, 0, 50)
    elif value <= 75:
        return linear_scale(value, 36, 75, 51, 100)
    elif value <= 185:
        return linear_scale(value, 76, 185, 101, 150)
    elif value <= 304:
        return linear_scale(value, 186, 304, 151, 200)
    elif value <= 604:
        return linear_scale(value, 305, 604, 201, 300)
    elif value <= 804:
        return linear_scale(value, 605, 804, 301, 400)
    elif value <= 1004:
        return linear_scale(value, 805, 1004, 401, 500)
    else:
        return 500  # AQI value capped at 500 for SO2

# Assuming 'clean_data1' is your DataFrame
clean_data1['AQI_O3'] = clean_data1['O3'].apply(calculate_aqi_o3)
clean_data1['AQI_PM2.5'] = clean_data1['PM2.5'].apply(calculate_aqi_pm25)
clean_data1['AQI_NO2'] = clean_data1['NO2'].apply(calculate_aqi_no2)
clean_data1['AQI_PM10'] = clean_data1['PM10'].apply(calculate_aqi_pm10)
clean_data1['AQI_CO'] = clean_data1['CO'].apply(calculate_aqi_co)
clean_data1['AQI_NO'] = clean_data1['NO'].apply(calculate_aqi_no)
clean_data1['AQI_NOx'] = clean_data1['NOx'].apply(calculate_aqi_nox)
clean_data1['AQI_SO2'] = clean_data1['SO2'].apply(calculate_aqi_so2)

# Function to determine AQI category
def classify_aqi(aqi):
    if aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Moderate'
    elif aqi <= 150:
        return 'Unhealthy for Sensitive Groups'
    elif aqi <= 200:
        return 'Unhealthy'
    elif aqi <= 300:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

# Calculate the maximum AQI and classify
clean_data1['Max_AQI'] = clean_data1[['AQI_O3', 'AQI_PM2.5', 'AQI_NO2', 'AQI_PM10', 'AQI_CO', 'AQI_NO', 'AQI_NOx', 'AQI_SO2']].max(axis=1)
clean_data1['AQI_Category'] = clean_data1['Max_AQI'].apply(classify_aqi)

# Print the updated DataFrame
print("Updated DataFrame with AQI and Categories:")
print(clean_data1.head())
# Out:
# Updated DataFrame with AQI and Categories:
#    location_id location_name   O3  DateLocal    DateUtc   TimeUtc DayOfWeek  \
# 0      2163091     Bucharest  0.0 2024-01-29 2024-01-28  23:00:00    Sunday
# 1      2163091     Bucharest  0.0 2024-01-29 2024-01-29  00:00:00    Monday
# 2      2163091     Bucharest  0.0 2024-01-29 2024-01-29  01:00:00    Monday
# 3      2163091     Bucharest  0.0 2024-01-29 2024-01-29  02:00:00    Monday
# 4      2163091     Bucharest  0.0 2024-01-29 2024-01-29  03:00:00    Monday
#
#   DayDescription  PM2.5   NO2  ...  AQI_O3  AQI_PM2.5    AQI_NO2   AQI_PM10  \
# 0    Working Day    0.0  47.0  ...     0.0        0.0  44.339623  12.962963
# 1    Working Day    0.0  43.0  ...     0.0        0.0  40.566038  12.962963
# 2    Working Day    0.0  37.0  ...     0.0        0.0  34.905660  13.888889
# 3    Working Day    0.0  33.0  ...     0.0        0.0  31.132075  13.888889
# 4    Working Day    0.0  40.0  ...     0.0        0.0  37.735849  13.888889
#
# ...

# %%
clean_data1[""]

# %%
clean_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16690 entries, 0 to 16689
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location_id     16690 non-null  int64
#  1   location_name   16690 non-null  object
#  2   O3              16690 non-null  float64
#  3   DateLocal       16690 non-null  datetime64[ns]
#  4   DateUtc         16690 non-null  datetime64[ns]
#  5   TimeUtc         16690 non-null  object
#  6   DayOfWeek       16690 non-null  object
#  7   DayDescription  16690 non-null  object
#  8   PM2.5           16690 non-null  float64
#  9   NO2             16690 non-null  float64
#  10  PM10            16690 non-null  float64
#  11  CO              16690 non-null  float64
#  12  NO              16690 non-null  float64
#  13  NOx             16690 non-null  float64
#  14  SO2             16690 non-null  float64
#  15  AQI_O3          16690 non-null  float64
# ...

# %%
clean_data1[clean_data1["location_name"]=="Nairobi"][["PM2.5"]]
# Out:
#        PM2.5
# 8944     6.4
# 8945     9.1
# 8946     8.8
# 8947     9.3
# 8948    11.0
# ...      ...
# 12258    9.2
# 12259   14.0
# 12260   15.0
# 12261   16.0
# 12262   15.0
#
# [3319 rows x 1 columns]

# %%
# Define a function to calculate AQI
import numpy as np
def calculate_aqi(row):
    pollutants = ['O3', 'PM10','PM2.5', 'NO2', 'CO', 'NO','NOx', 'SO2']
    aqi_values = row[pollutants].values
    max_aqi = np.max(aqi_values)
    max_pollutant = pollutants[np.argmax(aqi_values)]
    return max_aqi, max_pollutant

# Apply the function to each row to get maximum AQI and corresponding pollutant
clean_data1[['Max_AQI', 'Max_Pollutant']] = clean_data1.apply(calculate_aqi, axis=1, result_type='expand')

# Print the updated DataFrame to verify
print(clean_data1.head())
clean_data1
# Out:
#    location_id location_name   O3  DateLocal    DateUtc   TimeUtc DayOfWeek  \
# 0      2163091     Bucharest  0.0 2024-01-29 2024-01-28  23:00:00    Sunday
# 1      2163091     Bucharest  0.0 2024-01-29 2024-01-29  00:00:00    Monday
# 2      2163091     Bucharest  0.0 2024-01-29 2024-01-29  01:00:00    Monday
# 3      2163091     Bucharest  0.0 2024-01-29 2024-01-29  02:00:00    Monday
# 4      2163091     Bucharest  0.0 2024-01-29 2024-01-29  03:00:00    Monday
#
#   DayDescription  PM2.5   NO2  ...  AQI_PM2.5    AQI_NO2   AQI_PM10  AQI_CO  \
# 0    Working Day    0.0  47.0  ...        0.0  44.339623  12.962963   496.0
# 1    Working Day    0.0  43.0  ...        0.0  40.566038  12.962963   496.0
# 2    Working Day    0.0  37.0  ...        0.0  34.905660  13.888889   496.0
# 3    Working Day    0.0  33.0  ...        0.0  31.132075  13.888889   496.0
# 4    Working Day    0.0  40.0  ...        0.0  37.735849  13.888889   496.0
#
# ...

# %%
# Apply the function to each row
clean_data1[['Max_AQI', 'Max_Pollutant']] = clean_data1.apply(calculate_aqi, axis=1, result_type='expand')

# Define function to classify AQI
def classify_aqi(aqi):
    if aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Moderate'
    elif aqi <= 150:
        return 'Unhealthy for Sensitive Groups'
    elif aqi <= 200:
        return 'Unhealthy'
    elif aqi <= 300:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

# Apply classification to Max_AQI
clean_data1['AQI_Category'] = clean_data1['Max_AQI'].apply(classify_aqi)

# Print the updated DataFrame to verify
print(clean_data1)
# Out:
#        location_id location_name    O3  DateLocal    DateUtc   TimeUtc  \
# 0          2163091     Bucharest   0.0 2024-01-29 2024-01-28  23:00:00
# 1          2163091     Bucharest   0.0 2024-01-29 2024-01-29  00:00:00
# 2          2163091     Bucharest   0.0 2024-01-29 2024-01-29  01:00:00
# 3          2163091     Bucharest   0.0 2024-01-29 2024-01-29  02:00:00
# 4          2163091     Bucharest   0.0 2024-01-29 2024-01-29  03:00:00
# ...            ...           ...   ...        ...        ...       ...
# 16685         7529          Rome  32.0 2024-07-03 2024-07-03  20:00:00
# 16686         7529          Rome  47.0 2024-07-03 2024-07-03  21:00:00
# 16687         7529          Rome  41.0 2024-07-04 2024-07-03  22:00:00
# 16688         7529          Rome  34.0 2024-07-04 2024-07-03  23:00:00
# 16689         7529          Rome  23.0 2024-07-04 2024-07-04  00:00:00
#
#        DayOfWeek DayDescription      PM2.5   NO2  ...  AQI_PM2.5    AQI_NO2  \
# ...

# %%
clean_data1["location_name"].value_counts()
# Out:
# location_name
# Rome           4427
# Los Angeles    3934
# Nairobi        3319
# Bucharest      2535
# Madrid         2475
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming clean_data1 is your DataFrame
# Extract the Max_Pollutant for each city and count occurrences
city_pollutant_counts = clean_data1.groupby('location_name')['Max_Pollutant'].value_counts().unstack().fillna(0)

# Get the total count of major pollutants for each city
city_pollutant_totals = city_pollutant_counts.sum(axis=0)

print("City Pollutant Totals:")
print(city_pollutant_totals)
# Out:
# City Pollutant Totals:
# Max_Pollutant
# CO       2263.0
# NO2       587.0
# NOx      1667.0
# O3       4423.0
# PM10      588.0
# PM2.5    7162.0
# dtype: float64

# %%
# Plot pie chart
plt.figure(figsize=(10, 7))
plt.pie(city_pollutant_totals, labels=city_pollutant_totals.index, autopct='%1.1f%%', colors=plt.get_cmap('Set1').colors)
plt.title('Distribution of Major Pollutants Across Cities')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrame (replace with your actual DataFrame)
# clean_data1 should already be defined with your data

# Extract the Max_Pollutant for each city and count occurrences
city_pollutant_counts = clean_data1.groupby('location_name')['Max_Pollutant'].value_counts().unstack().fillna(0)

print("City Pollutant Counts:")
print(city_pollutant_counts)

# Function to plot pie chart for each city
def plot_pie_chart(city_name, data):
    plt.figure(figsize=(8, 6))
    plt.pie(data, labels=data.index, autopct='%1.1f%%', colors=plt.get_cmap('Set1').colors)
    plt.title(f'Distribution of Major Pollutants Based on Max AQI Value in {city_name}')
    plt.show()

# Iterate over each city and plot the pie chart
for city in city_pollutant_counts.index:
    plot_pie_chart(city, city_pollutant_counts.loc[city])
# Out:
# City Pollutant Counts:
# Max_Pollutant      CO    NO2     NOx      O3   PM10   PM2.5
# location_name
# Bucharest      2263.0  142.0     0.0     0.0  130.0     0.0
# Los Angeles       0.0    0.0     0.0    86.0    0.0  3848.0
# Madrid            0.0  214.0     0.0  2008.0  253.0     0.0
# Nairobi           0.0    0.0     0.0     5.0    0.0  3314.0
# Rome              0.0  231.0  1667.0  2324.0  205.0     0.0

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data preparation (replace with your actual data)
# Assume clean_data1 is your DataFrame with columns: DateLocal, O3, PM2.5, NO2, PM10, CO, NO, NOx, SO2, location_name

# Convert DateLocal to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Get unique cities
cities = clean_data1['location_name'].unique()

# Plotting scatter plots for each city
plt.figure(figsize=(14, 10))

for city in cities:
    city_data = clean_data1[clean_data1['location_name'] == city]
    
    plt.scatter(city_data['DateLocal'], city_data['O3'], label=f'{city} - O3', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['PM2.5'], label=f'{city} - PM2.5', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['NO2'], label=f'{city} - NO2', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['PM10'], label=f'{city} - PM10', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['CO'], label=f'{city} - CO', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['NO'], label=f'{city} - NO', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['NOx'], label=f'{city} - NOx', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['SO2'], label=f'{city} - SO2', alpha=0.5)

    plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1))

plt.xlabel('Date')
plt.ylabel('Pollutant Values')
plt.title('Scatter Plot of Pollutant Values Over Time by City')
plt.grid(True)  # Add grid for better readability
plt.xticks(rotation=45)  # Rotate x-axis labels for better fit

plt.tight_layout()  # Adjust layout to prevent overlap of labels

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data preparation (replace with your actual data)
# Assume clean_data1 is your DataFrame with columns: DateLocal, O3, PM2.5, NO2, PM10, CO, NO, NOx, SO2, location_name

# Convert DateLocal to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Get unique cities
cities = clean_data1['location_name'].unique()

# Create a separate plot for each city
for city in cities:
    city_data = clean_data1[clean_data1['location_name'] == city]
    
    plt.figure(figsize=(12, 8))
    plt.scatter(city_data['DateLocal'], city_data['O3'], label='O3', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['PM2.5'], label='PM2.5', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['NO2'], label='NO2', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['PM10'], label='PM10', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['CO'], label='CO', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['NO'], label='NO', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['NOx'], label='NOx', alpha=0.5)
    plt.scatter(city_data['DateLocal'], city_data['SO2'], label='SO2', alpha=0.5)

    plt.xlabel('Date')
    plt.ylabel('Pollutant Values')
    plt.title(f'Scatter Plot of Pollutant Values Over Time for {city}')
    plt.legend(loc='upper right')
    plt.grid(True)  # Add grid for better readability
    plt.xticks(rotation=45)  # Rotate x-axis labels for better fit

    plt.tight_layout()  # Adjust layout to prevent overlap of labels

    # Save or show the plot
    plt.savefig(f'{city}_pollutants.png')  # Save the figure
    plt.show()  # Show the figure

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example function to categorize AQI values
def categorize_aqi(aqi):
    if aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Moderate'
    elif aqi <= 150:
        return 'Unhealthy for Sensitive Groups'
    elif aqi <= 200:
        return 'Unhealthy'
    elif aqi <= 300:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

# Assuming clean_data1 is your DataFrame with columns: Max_AQI, location_name
# Apply categorization
clean_data1['AQI_Category'] = clean_data1['Max_AQI'].apply(categorize_aqi)

# Get unique cities
cities = clean_data1['location_name'].unique()

# Create a separate pie chart for each city
for city in cities:
    city_data = clean_data1[clean_data1['location_name'] == city]
    
    # Count the number of occurrences in each AQI category
    category_counts = city_data['AQI_Category'].value_counts()
    
    plt.figure(figsize=(8, 8))
    plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(category_counts))))
    plt.title(f'AQI Category Distribution for {city}')
    
    # Save or show the pie chart
    plt.savefig(f'{city}_aqi_distribution.png')  # Save the figure
    plt.show()  # Show the figure

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame (replace with your actual DataFrame)
# clean_data1 = pd.DataFrame({...})

# Convert 'DateLocal' to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Ensure 'Max_AQI' is numeric
clean_data1['Max_AQI'] = pd.to_numeric(clean_data1['Max_AQI'], errors='coerce')

# Group by date and city, then calculate the max AQI for each date
time_series_data = clean_data1.groupby(['DateLocal', 'location_name'])['Max_AQI'].max().reset_index()

# Create the plot
plt.figure(figsize=(14, 8))

# Plot time series for each city
for city in time_series_data['location_name'].unique():
    city_data = time_series_data[time_series_data['location_name'] == city]
    plt.plot(city_data['DateLocal'], city_data['Max_AQI'], label=city)

# Set labels and title
plt.xlabel('Date')
plt.ylabel('Max AQI')
plt.title('Time Series of Max AQI for Different Cities')
plt.legend()  # Show legend with city names

plt.grid(True)  # Add grid for better readability
plt.xticks(rotation=45)  # Rotate x-axis labels for better fit
plt.tight_layout()  # Adjust layout to prevent overlap of labels

# Save or show the plot
plt.savefig('time_series_max_aqi_comparison.png')  # Save the figure
plt.show()  # Show the figure

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame creation (replace with your actual DataFrame)
# Assuming clean_data1 is your DataFrame with columns: DateLocal, location_name, Max_AQI, DayDescription

# Convert DateLocal to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Aggregate the data to get the maximum AQI for each city and day type
avg_aqi_daytype = clean_data1.groupby(['location_name', 'DayDescription'])['Max_AQI'].mean().reset_index()

# Pivot the data for easier plotting
pivot_aqi = avg_aqi_daytype.pivot(index='DayDescription', columns='location_name', values='Max_AQI')

# Plotting
plt.figure(figsize=(12, 8))

# Bar plot for each city
pivot_aqi.plot(kind='bar', width=0.8, figsize=(14, 8))

# Set labels and title
plt.xlabel('Day Description')
plt.ylabel('Average Maximum AQI')
plt.title('Average Maximum AQI for Different Cities by Day Type')
plt.legend(title='City')

plt.grid(True, axis='y')  # Add grid for better readability
plt.xticks(rotation=0)  # Rotate x-axis labels for better fit

plt.tight_layout()  # Adjust layout to prevent overlap of labels

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame creation (replace with your actual DataFrame)
# Assuming clean_data1 is your DataFrame with columns: DateLocal, location_name, Max_AQI, DayDescription

# Convert DateLocal to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Filter for only 'Weekend', 'Holiday', and 'Workday'
filtered_data = clean_data1[clean_data1['DayDescription'].isin(['Weekend', 'Holiday', 'Workday'])]

# Aggregate the data to get the average maximum AQI for each city and day type
avg_aqi_daytype = filtered_data.groupby(['location_name', 'DayDescription'])['Max_AQI'].mean().reset_index()

# Pivot the data for easier plotting
pivot_aqi = avg_aqi_daytype.pivot(index='DayDescription', columns='location_name', values='Max_AQI')

# Ensure the x-axis has only 'Weekend', 'Holiday', and 'Workday'
pivot_aqi = pivot_aqi.reindex(['Weekend', 'Holiday', 'Workday'])

# Plotting
plt.figure(figsize=(14, 8))

# Bar plot for each city
pivot_aqi.plot(kind='bar', width=0.8, figsize=(14, 8))

# Set labels and title
plt.xlabel('Day Description')
plt.ylabel('Average Maximum AQI')
plt.title('Average Maximum AQI for Different Cities by Day Type')
plt.legend(title='City')

plt.grid(True, axis='y')  # Add grid for better readability
plt.xticks(rotation=0)  # Rotate x-axis labels for better fit

plt.tight_layout()  # Adjust layout to prevent overlap of labels

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 26
#      23 plt.figure(figsize=(14, 8))
#      25 # Bar plot for each city
# ---> 26 pivot_aqi.plot(kind='bar', width=0.8, figsize=(14, 8))
#      28 # Set labels and title
#      29 plt.xlabel('Day Description')
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
clean_data1["DayOfWeek"]
# Out:
# 0           Sunday
# 1           Monday
# 2           Monday
# 3           Monday
# 4           Monday
#            ...
# 16685    Wednesday
# 16686    Wednesday
# 16687    Wednesday
# 16688    Wednesday
# 16689     Thursday
# Name: DayOfWeek, Length: 16690, dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame (replace with your actual DataFrame)
# Assuming clean_data1 is your DataFrame with columns: DateLocal, location_name, Max_AQI, DayOfWeek

# Define day categories
def categorize_day(day_of_week):
    if day_of_week in ['Saturday', 'Sunday']:
        return 'Weekend'
    elif day_of_week in ['Friday', 'Saturday', 'Sunday']:  # Adjust this if you have specific holidays
        return 'Holiday'
    else:
        return 'Workday'

# Add DayDescription to DataFrame
clean_data1['DayDescription'] = clean_data1['DayOfWeek'].apply(categorize_day)

# Aggregate the data to get the average maximum AQI for each city and day type
avg_aqi_daytype = clean_data1.groupby(['location_name', 'DayDescription'])['Max_AQI'].mean().reset_index()

# Pivot the data for easier plotting
pivot_aqi = avg_aqi_daytype.pivot(index='DayDescription', columns='location_name', values='Max_AQI')

# Ensure the x-axis has only 'Weekend', 'Holiday', and 'Workday'
pivot_aqi = pivot_aqi.reindex(['Weekend', 'Holiday', 'Workday'])

# Plotting
plt.figure(figsize=(14, 8))

# Bar plot for each city
pivot_aqi.plot(kind='bar', width=0.8, figsize=(14, 8))

# Set labels and title
plt.xlabel('Day Description')
plt.ylabel('Average Maximum AQI')
plt.title('Average Maximum AQI for Different Cities by Day Type')
plt.legend(title='City')

plt.grid(True, axis='y')  # Add grid for better readability
plt.xticks(rotation=0)  # Rotate x-axis labels for better fit

plt.tight_layout()  # Adjust layout to prevent overlap of labels

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace with your actual DataFrame)
# Assuming clean_data1 is your DataFrame with columns: DateLocal, location_name, Max_AQI

# Convert 'DateLocal' to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Extract the day of the week
clean_data1['DayOfWeek'] = clean_data1['DateLocal'].dt.day_name()

# Aggregate AQI by Day of the Week
daily_aqi = clean_data1.groupby(['DayOfWeek'])['Max_AQI'].mean().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# Plotting
plt.figure(figsize=(10, 6))

# Line plot for daily AQI trends
plt.plot(daily_aqi.index, daily_aqi, marker='o', linestyle='-', color='b')

# Set labels and title
plt.xlabel('Day of the Week')
plt.ylabel('Average Maximum AQI')
plt.title('Daily Average Maximum AQI by Day of the Week')

plt.grid(True)  # Add grid for better readability
plt.xticks(rotation=45)  # Rotate x-axis labels for better fit

plt.tight_layout()  # Adjust layout to prevent overlap of labels

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace with your actual DataFrame)
# Assuming clean_data1 is your DataFrame with columns: DateLocal, location_name, Max_AQI

# Convert 'DateLocal' to datetime if it's not already
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'])

# Extract the day of the week
clean_data1['DayOfWeek'] = clean_data1['DateLocal'].dt.day_name()

# List of cities
cities = clean_data1['location_name'].unique()

# Create a figure for the plots
plt.figure(figsize=(16, 12))

for city in cities:
    # Filter data for the current city
    city_data = clean_data1[clean_data1['location_name'] == city]
    
    # Aggregate AQI by Day of the Week
    daily_aqi = city_data.groupby('DayOfWeek')['Max_AQI'].mean().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
    
    # Plotting
    plt.subplot(len(cities), 1, list(cities).index(city) + 1)  # Create a subplot for each city
    plt.plot(daily_aqi.index, daily_aqi, marker='o', linestyle='-', label=city)
    
    # Set labels and title
    plt.xlabel('Day of the Week')
    plt.ylabel('Average Maximum AQI')
    plt.title(f'Daily Average Maximum AQI for {city}')
    plt.grid(True)  # Add grid for better readability

plt.tight_layout()  # Adjust layout to prevent overlap of labels
plt.show()

# %%
# Summary statistics for Max_AQI
summary_stats = clean_data1['Max_AQI'].describe()
print("Summary Statistics for Max_AQI:")
print(summary_stats)
# Out:
# Summary Statistics for Max_AQI:
# count    16690.000000
# mean       160.406343
# std        188.792336
# min          0.000000
# 25%         47.000000
# 50%         62.000000
# 75%        180.000000
# max        500.000000
# Name: Max_AQI, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'clean_data1' is your DataFrame
# Filter data for Nairobi
nairobi_data = clean_data1[clean_data1['location_name'] == 'Nairobi']

# Ensure PM2.5 column is present
if 'PM2.5' not in nairobi_data.columns:
    raise ValueError("PM2.5 column not found in the DataFrame")

# Set PM2.5 values to zero if missing
nairobi_data['PM2.5'] = nairobi_data['PM2.5'].fillna(0)

# Summary Statistics
summary_stats_pm25 = nairobi_data['PM2.5'].describe()

# Plotting
plt.figure(figsize=(16, 12))

# Histogram
plt.subplot(2, 2, 1)
sns.histplot(nairobi_data['PM2.5'], bins=30, kde=True)
plt.xlabel('PM2.5')
plt.ylabel('Frequency')
plt.title('Histogram of PM2.5 Levels in Nairobi')
plt.grid(True)

# Box Plot
plt.subplot(2, 2, 2)
sns.boxplot(y=nairobi_data['PM2.5'])
plt.ylabel('PM2.5')
plt.title('Box Plot of PM2.5 Levels in Nairobi')
plt.grid(True)

# Scatter Plot (if you have DateLocal, you can uncomment and use this)
if 'DateLocal' in nairobi_data.columns:
    plt.subplot(2, 2, 3)
    plt.scatter(nairobi_data['DateLocal'], nairobi_data['PM2.5'], alpha=0.5)
    plt.xlabel('Date')
    plt.ylabel('PM2.5')
    plt.title('Scatter Plot of PM2.5 Levels in Nairobi Over Time')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()

# Print summary statistics
print("Summary Statistics for PM2.5 in Nairobi:")
print(summary_stats_pm25)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17348\1411230674.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nairobi_data['PM2.5'] = nairobi_data['PM2.5'].fillna(0)
# Summary Statistics for PM2.5 in Nairobi:
# count    3319.000000
# mean       49.363543
# std        65.616742
# min         0.000000
# 25%         7.700000
# 50%        12.000000
# 75%        75.500000
# max       210.000000
# Name: PM2.5, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'clean_data1' is your DataFrame

# Ensure the 'DateLocal' column is in datetime format
clean_data1['DateLocal'] = pd.to_datetime(clean_data1['DateLocal'], errors='coerce')

# Extract month and year from the date
clean_data1['Month'] = clean_data1['DateLocal'].dt.to_period('M')
clean_data1['Year'] = clean_data1['DateLocal'].dt.year

# List of pollutants to include in AQI calculation
pollutants = ['AQI_O3', 'AQI_PM2.5', 'AQI_NO2', 'AQI_PM10', 'AQI_CO', 'AQI_NO', 'AQI_NOx', 'AQI_SO2']

# Create a DataFrame to store the monthly average AQI for each city
monthly_aqi = clean_data1.groupby(['location_name', 'Year', 'Month'])[pollutants].mean().reset_index()

# Pivot the DataFrame for heatmap plotting
heatmap_data = monthly_aqi.pivot_table(index=['Year', 'Month'], columns='location_name', values='AQI_O3')

# Plot heatmap for AQI_O3 as an example; you can iterate over other pollutants similarly
plt.figure(figsize=(14, 8))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt=".1f", linewidths=0.5)
plt.title('Average Monthly AQI_O3 by City')
plt.xlabel('City')
plt.ylabel('Year-Month')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
